# %%
import pandas as pd

# %%
src_subject_id
masc_ma7
masc_ma16
masc_ma18
masc_ma22
masc_ma23
masc_ma31
masc_ma12sax
masc_ma21px
masc_ma22acx
masc_ma31hfx
masc_ma32pfx
masc_ma1phyx
masc_ma2hat
masc_ma3socx
masc_ma4sepx
masc_matotalx
snap_sna19
snap_sna20
snap_sna21
snap_sna22
snap_sna23
snap_sna24
snap_sna25
snap_sna26
snap_sna27
snap_sna28
snap_sna29
snap_sna30
snap_sna31
snap_sna32
snap_sna33
snap_sna34
snap_sna35
snap_sna36
snap_sna37
snap_sna38
snap_sna39
snap_snainatt
snap_snahypat
snap_snaimput
snap_snaaddwt
snap_snaoddt
snap_snatotlt
snap_snahyimx
snap_snaadhdt
snap_snahit
snap_snadbdx
snap_snap_adhd_1
snap_snap_adhd_2
snap_snap_adhd_3
snap_snap_adhd_4
snap_snap_adhd_5
snap_snap_adhd_6
snap_snap_adhd_7
snap_snap_adhd_8
snap_snap_adhd_9
snap_snap_adhd_11
snap_snap_adhd_12
snap_snap_adhd_13
snap_snap_adhd_14
snap_snap_adhd_15
snap_snap_adhd_16
snap_snap_adhd_17
snap_snap_adhd_18
snap_snap_adhd_19
cbcl_sports_time3
cbcl_sports_well3
cbcl_activities_time2
cbcl_activities_well2
cbcl_clubs_active1
cbcl_chores_well1
cbcl_chores_well2
pcrc_pcc21
pcrc_pcc22
pcrc_pcc23
pcrc_pcc24
pcrc_pcc25
pcrc_pcc26
pcrc_pcc27
pcrc_pcc28
pcrc_pcc29
pcrc_pcc30
pcrc_pcc31
pcrc_pcc32
pcrc_pcc33
pcrc_pcc34
pcrc_pcc35
pcrc_pcc36
pcrc_pcc37
pcrc_pcc38
pcrc_pcc39
pcrc_pcc40
pcrc_pcrcposx
pcrc_pcrcprox
pcrc_pcrcaffx
pcrc_pcrcqurx
pcrc_pcrcsocx
pcrc_pcrcsimx
pcrc_pcrcprax
pcrc_pcrcdomx
pcrc_pcrcintx
pcrc_pcrcppnx
pcrc_pcrcadpx
pcrc_pcrcadcx
pcrc_pcrcprix
pcrc_pcrcnurx
pcrc_pcrcvpnx
pcrc_pcrcdecx
pcrc_pcrccomx
pcrc_pcrcgltx
pcrc_pcrcratx
pcrc_pcrcpox
pcrc_pcrcwx
pcrc_pcrcpax
pcrc_pcrcprx
pcrc_pcrcdwx
ssrs_s7t35
ssrs_s7t36
ssrs_s7t45
ssrs_s7t46
ssrs_sst15
ssrs_sst16
ssrs_sst19
ssrs_sst20
ssrs_sst37
ssrs_sst38
ssrs_sst43
ssrs_sst44
ssrs_sst47
ssrs_sst48
ssrs_s7t62
ssrs_s7t63
ssrs_s7t64
ssrs_s7t65
ssrs_s7t66
ssrs_s7t67
ssrs_s7t68
ssrs_s7t69
ssrs_s7t70
ssrs_s7t71
ssrs_s7t72
ssrs_sst65
ssrs_sst67
ssrs_sst70
ssrs_sst77
ssrs_sst78
ssrs_sspcoopt
ssrs_sspasrtt
ssrs_sspscont
ssrs_ssptosst
ssrs_sspextt
ssrs_sspintt
ssrs_ssphypt
ssrs_ssptopbt
scid_q092_phobia_life
scid_q094_ocd_life
scid_q114_an_life
scid_q116_bn_life
scid_bpl
scid_gadc
scid_somatc
scid_undfsomc
scid_hypoconc
scid_othdsml
scid_axisidx
scid_certmood
scid_certsubs
scid_certanx
scid_certsom
scid_certeat
scid_certadj
scid_ethnic_group
scid_das1ms
scid_grade_highed
scid_pastpsy
scid_scid19
scid_mdca1
scid_mdca2
scid_maniachk
scid_mala
scid_dyschk
scid_dya
scid_psref
scid_psper
scid_psgra
scid_pssom
scid_psaud
scid_psvis
scid_pstac
scid_psnotorg
scid_mochk1
scid_sualchk
scid_sesed
scid_sucan
scid_susti
scid_suopi
scid_sucoc
scid_suhal
scid_suoth
scid_suany
scid_axpana
scid_axawpa
scid_axsoca
scid_axsima
scid_axoca1
scid_axoc1
scid_axgada
scid_smchk1
scid_smchk2
scid_edanoa
scid_edbula
scid_adjchk
scid_q018_obp_life
scid_q021_mdd_life
scid_q028_dysd_current
scid_q067_al_life
scid_q069_sha_life
scid_q071_can_life
scid_q073_stim_life
scid_q075_op_life
scid_q077_coc_life
scid_q079_hal_life
scid_q081_poly_life
scid_q083_othsub_life
scid_q085_panic_life
scid_q088_agor_life
scid_q090_social_life
scid_depsnpdl
scid_sompainc
'expect_exp1_m',
 'expect_exp2_m',
 'expect_exp3_m',
 'expect_exp4_m',
 'expect_exp5_m',
 'expect_exp6_m',
 'expect_exptott_m',
 'expect_exp1_f',
 'expect_exp2_f',
 'expect_exp3_f',
 'expect_exp4_f',
 'expect_exp5_f',
 'expect_exp6_f',
 'expect_exptott_f'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 src_subject_id
#       2 masc_ma7
#       3 masc_ma16
#
# NameError: name 'src_subject_id' is not defined

# %%
data = {
    "Variable Name": [
        "cbcl_sports_time3",
        "cbcl_sports_well3",
        "cbcl_activities_time2",
        "cbcl_activities_well2",
        "cbcl_clubs_active1",
        "cbcl_chores_well1",
        "cbcl_chores_well2"
    ],
    "ElementDescription": [
        "Amount of time spent on sport3",
        "How well youth does sport3",
        "Amount of time spent on activity2",
        "How well youth does activity2",
        "How active youth is in club1",
        "How well youth does chore1",
        "How well youth does chore2"
    ],
    "Notes": [
        "0 = Less than average; 1 = Average; 2 = More than average; 3 = Don't know",
        "0 = Below average; 1 = Average; 2 = Above average; 3 = Don't know",
        "0 = Less than average; 1 = Average; 2 = More than average; 3 = Don't know;9 = Missing",
        "0 = Below average; 1 = Average; 2 = Above average; 3 = Don't know;9 = Missing",
        "0 = Less active; 1 = Average; 2 = Above average; 3 = Don't know; 999=missing/NA",
        "0 = Below average; 1 = Average; 2 = Above average; 3 = Don't know; 999= missing/NA",
        "0 = Below average; 1 = Average; 2 = Above average; 3 = Don't know; 999= missing/NA"
    ]
}

df_cbcl = pd.DataFrame(data)

# %%
data = [
    # 1. snap_sna19 => sna19
    {
        "Questionnaire": "snap",
        "ElementName": "sna19",
        "ElementDescription": "Stared into space and reported daydreaming",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 2. snap_sna20 => sna20
    {
        "Questionnaire": "snap",
        "ElementName": "sna20",
        "ElementDescription": "Were low in energy level, sluggish, or drowsy",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 3. snap_sna21 => sna21
    {
        "Questionnaire": "snap",
        "ElementName": "sna21",
        "ElementDescription": "Were apathetic or unmotivated to engage in goal directed activities",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 4. snap_sna22 => sna22
    {
        "Questionnaire": "snap",
        "ElementName": "sna22",
        "ElementDescription": "Engaged in physically dangerous activities without considering possible consequences",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 5. snap_sna23 => sna23
    {
        "Questionnaire": "snap",
        "ElementName": "sna23",
        "ElementDescription": "Shifted from one uncompleted activity to another",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 6. snap_sna24 => sna24
    {
        "Questionnaire": "snap",
        "ElementName": "sna24",
        "ElementDescription": "Failed to finish things",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 7. snap_sna25 => sna25
    {
        "Questionnaire": "snap",
        "ElementName": "sna25",
        "ElementDescription": "Had difficulty concentrating on school work or other tasks requiring sustained attention",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 8. snap_sna26 => sna26
    {
        "Questionnaire": "snap",
        "ElementName": "sna26",
        "ElementDescription": "Had difficulty sticking to a play activity",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 9. snap_sna27 => sna27
    {
        "Questionnaire": "snap",
        "ElementName": "sna27",
        "ElementDescription": "Called out in class or in other situations when silence was expected",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 10. snap_sna28 => sna28
    {
        "Questionnaire": "snap",
        "ElementName": "sna28",
        "ElementDescription": "Needed a lot of supervision",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 11. snap_sna29 => sna29
    {
        "Questionnaire": "snap",
        "ElementName": "sna29",
        "ElementDescription": "Moved about excessively (e.g., even during sleep at home or during quiet time at school)",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 12. snap_sna30 => sna30
    {
        "Questionnaire": "snap",
        "ElementName": "sna30",
        "ElementDescription": "Acted before thinking",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 13. snap_sna31 => sna31
    {
        "Questionnaire": "snap",
        "ElementName": "sna31",
        "ElementDescription": "Lost temper",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 14. snap_sna32 => sna32
    {
        "Questionnaire": "snap",
        "ElementName": "sna32",
        "ElementDescription": "Argued with adults",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 15. snap_sna33 => sna33
    {
        "Questionnaire": "snap",
        "ElementName": "sna33",
        "ElementDescription": "Actively defied or refused adult requests or rules",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 16. snap_sna34 => sna34
    {
        "Questionnaire": "snap",
        "ElementName": "sna34",
        "ElementDescription": "Did things deliberately that annoy other people",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 17. snap_sna35 => sna35
    {
        "Questionnaire": "snap",
        "ElementName": "sna35",
        "ElementDescription": "Blamed others for mistakes or misbehavior",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 18. snap_sna36 => sna36
    {
        "Questionnaire": "snap",
        "ElementName": "sna36",
        "ElementDescription": "Were touchy or easily annoyed by others",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 19. snap_sna37 => sna37
    {
        "Questionnaire": "snap",
        "ElementName": "sna37",
        "ElementDescription": "Were angry and resentful",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 20. snap_sna38 => sna38
    {
        "Questionnaire": "snap",
        "ElementName": "sna38",
        "ElementDescription": "Were spiteful or vindictive",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 21. snap_sna39 => sna39
    {
        "Questionnaire": "snap",
        "ElementName": "sna39",
        "ElementDescription": "Swore or used obscene language",
        "Notes": "0=Not at all; 1=Just a little; 2=Pretty much; 3=Very much"
    },
    # 22. snap_snainatt => snainatt
    {
        "Questionnaire": "snap",
        "ElementName": "snainatt",
        "ElementDescription": "Inattention (total score)",
        "Notes": ""
    },
    # 23. snap_snahypat => snahypat
    {
        "Questionnaire": "snap",
        "ElementName": "snahypat",
        "ElementDescription": "Hyperactivity (total score)",
        "Notes": ""
    },
    # 24. snap_snaimput => snaimput
    {
        "Questionnaire": "snap",
        "ElementName": "snaimput",
        "ElementDescription": "Impulsivity (total score)",
        "Notes": ""
    },
    # 25. snap_snaaddwt => snaaddwt
    {
        "Questionnaire": "snap",
        "ElementName": "snaaddwt",
        "ElementDescription": "ADD/WO (total score)",
        "Notes": ""
    },
    # 26. snap_snaoddt => snaoddt
    {
        "Questionnaire": "snap",
        "ElementName": "snaoddt",
        "ElementDescription": "ODD (total score)",
        "Notes": ""
    },
    # 27. snap_snatotlt => snatotlt
    {
        "Questionnaire": "snap",
        "ElementName": "snatotlt",
        "ElementDescription": "SNAP- Adolescent Total Score (total score)",
        "Notes": ""
    },
    # 28. snap_snahyimx => snahyimx
    {
        "Questionnaire": "snap",
        "ElementName": "snahyimx",
        "ElementDescription": "SNAP- Adolescent Hyperactive/Impulsive (mean score)",
        "Notes": ""
    },
    # 29. snap_snaadhdt => snaadhdt
    {
        "Questionnaire": "snap",
        "ElementName": "snaadhdt",
        "ElementDescription": "ADHD (total score)",
        "Notes": ""
    },
    # 30. snap_snahit => snahit
    {
        "Questionnaire": "snap",
        "ElementName": "snahit",
        "ElementDescription": "Hyperactive/Impulsive (total score)",
        "Notes": ""
    },
    # 31. snap_snadbdx => snadbdx
    {
        "Questionnaire": "snap",
        "ElementName": "snadbdx",
        "ElementDescription": "SNAP Adolescent Composite DBD Mean Score",
        "Notes": ""
    },
    # 32. snap_snap_adhd_1 => snap_adhd_1
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_1",
        "ElementDescription": "1. Often fails to give close attention to details or makes careless mistakes in schoolwork or tasks",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 33. snap_snap_adhd_2 => snap_adhd_2
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_2",
        "ElementDescription": "2. Often has difficulty sustaining attention in tasks or play activities",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 34. snap_snap_adhd_3 => snap_adhd_3
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_3",
        "ElementDescription": "3. Often does not seem to listen when spoken to directly",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 35. snap_snap_adhd_4 => snap_adhd_4
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_4",
        "ElementDescription": "4. Often does not follow through on instructions and fails to finish schoolwork, chores, or duties",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 36. snap_snap_adhd_5 => snap_adhd_5
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_5",
        "ElementDescription": "5. Often has difficulty organizing tasks and activities",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 37. snap_snap_adhd_6 => snap_adhd_6
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_6",
        "ElementDescription": "6. Often avoids, dislikes, or reluctantly engages in tasks requiring sustained mental effort",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 38. snap_snap_adhd_7 => snap_adhd_7
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_7",
        "ElementDescription": "7. Often loses things necessary for activities (e.g., toys, school assignments, pencils, or books)",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 39. snap_snap_adhd_8 => snap_adhd_8
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_8",
        "ElementDescription": "8. Often is distracted by extraneous stimuli",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 40. snap_snap_adhd_9 => snap_adhd_9
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_9",
        "ElementDescription": "9. Often is forgetful in daily activities",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 41. snap_snap_adhd_11 => snap_adhd_11
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_11",
        "ElementDescription": "11. Often fidgets with hands or feet or squirms in seat",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 42. snap_snap_adhd_12 => snap_adhd_12
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_12",
        "ElementDescription": "12. Often leaves seat in classroom or in other situations in which remaining seated is expected",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 43. snap_snap_adhd_13 => snap_adhd_13
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_13",
        "ElementDescription": "13. Often runs about or climbs excessively in situations in which it is inappropriate",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 44. snap_snap_adhd_14 => snap_adhd_14
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_14",
        "ElementDescription": "14. Often has difficulty playing or engaging in leisure activities quietly",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 45. snap_snap_adhd_15 => snap_adhd_15
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_15",
        "ElementDescription": "15. Often is \"on the go\" or often acts as if \"driven by a motor\"",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 46. snap_snap_adhd_16 => snap_adhd_16
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_16",
        "ElementDescription": "16. Often talks excessively",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 47. snap_snap_adhd_17 => snap_adhd_17
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_17",
        "ElementDescription": "17. Often blurts out answers before questions have been completed",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 48. snap_snap_adhd_18 => snap_adhd_18
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_18",
        "ElementDescription": "18. Often has difficulty awaiting their turn",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    },
    # 49. snap_snap_adhd_19 => snap_adhd_19
    {
        "Questionnaire": "snap",
        "ElementName": "snap_adhd_19",
        "ElementDescription": "19. Often interrupts or intrudes on others (e.g., butts into conversations/games)",
        "Notes": "0::3; 999 => 0=not at all, 1=just a little, 2=quite a bit, 3=very much"
    }
]

# Convert this list of dictionaries to a pandas DataFrame
df_snap = pd.DataFrame(data)

# Display or return the DataFrame

# %%
expect_data = {
    "Variable Name": [
        "subjectkey",
        "src_subject_id",
        "interview_date",
        "interview_age",
        "sex",
        "days_baseline",
        "assbdic",
        "relationship",
        "actbdic",
        "site",
        "sjtyp",
        "exp1",
        "exp2",
        "exp3",
        "exp4",
        "exp5",
        "exp6",
        "exptotx",
        "exptott"
    ],
    "ElementDescription": [
        "The NDAR Global Unique Identifier (GUID) for research subject",
        "Subject ID how it's defined in lab/project",
        "Date on which the interview/genetic test/sampling/imaging/biospecimen was completed. MM/DD/YYYY",
        "Age in months at the time of the interview/test/sampling/imaging",
        "Sex of subject at birth",
        "Days since baseline",
        "Assessment Point",
        "Relationship of respondent to individual",
        "Active status",
        "Site",
        "Subject type",
        "Suppose you ask your child to clean up his/her room. Will your child do it?",
        "Imagine you are talking on the telephone and you ask your child to stop interrupting you. Will your child stop?",
        "Suppose you ask your child to behave during dinner. Will your child obey your request?",
        "Imagine you ask your child to get ready for bed. Will your child do it?",
        "Suppose you ask your child to come in from playing outside. Will your child obey your request?",
        "Imagine you ask your child to play nicely with another child. Will your child do it?",
        "Expectations Total (mean score)",
        "Expectations Total (total score)"
    ],
    "Notes": [
        "ValueRange: NDAR*",
        "",
        "",
        "",
        "",
        "",
        "Possible codes: D;14;E;24;LB;36;72;96;120; etc.",
        "Codes for relationship, e.g., 1=Biological mom, 2=Biological dad, …",
        "0::5 (0=Inactive, 1=Active, …)",
        "Study Site",
        "1=MTA randomized trial, 2=LNCG subject",
        "",
        "",
        "",
        "",
        "",
        "",
        "",
        ""
    ]
}

df_expect = pd.DataFrame(expect_data)

# %%
# Create a list of dictionaries, each entry corresponding to one variable
data = [
    {
        "ElementName": "ma7",
        "ElementDescription": "I don't like to do things in front of other people",
        "Notes": "0 = Never true; 1 = Rarely true; 2 = Sometimes true; 3 = Often true"
    },
    {
        "ElementName": "ma16",
        "ElementDescription": "I don't like to sleep by myself",
        "Notes": "0 = Never true; 1 = Rarely true; 2 = Sometimes true; 3 = Often true"
    },
    {
        "ElementName": "ma18",
        "ElementDescription": "I try not to upset anyone",
        "Notes": "0 = Never true; 1 = Rarely true; 2 = Sometimes true; 3 = Often true"
    },
    {
        "ElementName": "ma22",
        "ElementDescription": "I try not to think about things that might upset me",
        "Notes": "0 = Never true; 1 = Rarely true; 2 = Sometimes true; 3 = Often true"
    },
    {
        "ElementName": "ma23",
        "ElementDescription": "I try not to get called on in class",
        "Notes": "0 = Never true; 1 = Rarely true; 2 = Sometimes true; 3 = Often true"
    },
    {
        "ElementName": "ma31",
        "ElementDescription": "I don't like to speak in public",
        "Notes": "0 = Never true; 1 = Rarely true; 2 = Sometimes true; 3 = Often true"
    },
    {
        "ElementName": "ma12sax",
        "ElementDescription": "Somatic/autonomic raw score",
        "Notes": "Includes Items 5, 13, 21, 29, 37, 44."
    },
    {
        "ElementName": "ma21px",
        "ElementDescription": "Perfectionism raw score",
        "Notes": "Includes Items 2, 10, 18, 26, 34."
    },
    {
        "ElementName": "ma22acx",
        "ElementDescription": "Anxious coping raw score",
        "Notes": "Includes Items 6, 14, 22, 30, 38, 42."
    },
    {
        "ElementName": "ma31hfx",
        "ElementDescription": "Humilliation fears raw score",
        "Notes": "Includes Items 3, 11, 19, 27, 35, 43."
    },
    {
        "ElementName": "ma32pfx",
        "ElementDescription": "Performance fears raw score",
        "Notes": "Includes Items 7, 15, 23, 31, 39, 45."
    },
    {
        "ElementName": "ma1phyx",
        "ElementDescription": "Physical symptoms raw score",
        "Notes": "Includes Items 1, 5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 44."
    },
    {
        "ElementName": "ma2hat",
        "ElementDescription": "Harm avoidance total score",
        "Notes": "Includes Items 2, 6, 10, 14, 18, 22, 26, 30, 34, 38, 42."
    },
    {
        "ElementName": "ma3socx",
        "ElementDescription": "Social anxiety raw score",
        "Notes": "Includes Items 3, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43, 45."
    },
    {
        "ElementName": "ma4sepx",
        "ElementDescription": "Separation anxiety raw score",
        "Notes": "Includes Items 4, 8, 12, 16, 20, 24, 28, 32, 36, 40."
    },
    {
        "ElementName": "matotalx",
        "ElementDescription": "Total score raw score",
        "Notes": "Includes All Items 1 to 45."
    }
]

# Convert list of dictionaries to a pandas DataFrame
df_masc = pd.DataFrame(data)

# %%
data = [
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc21",  # pcrc_pcc21
        "ElementDescription": (
            "Child. How much does your mother not let you do something you want to do because she "
            "is afraid you might get hurt? Parent. How much do  you not let this child do something "
            "this child wants to do because you are afraid this child might get hurt?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc22",  # pcrc_pcc22
        "ElementDescription": (
            "Child. How much do you and your mother love each other? Parent. How much do this child "
            "and you love each other?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc23",  # pcrc_pcc23
        "ElementDescription": (
            "Child. How much do you and your mother get mad at and get in arguments with each other? "
            "Parent. How much do this child and you get mad at and get in arguments with each other?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc24",  # pcrc_pcc24
        "ElementDescription": (
            "Child. How much do you and your mother give each other a hand with things? "
            "Parent. How much do this child and you give each other a hand with things?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc25",  # pcrc_pcc25
        "ElementDescription": (
            "Child. Some parents and children have a lot of things in common, while other parents "
            "and children have a little in common. How much do you and your mother have things in common? "
            "Parent. ... How much do this child and you have things in common?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc26",  # pcrc_pcc26
        "ElementDescription": (
            "Child. How much does your mother tell you that you did a good job? "
            "Parent. How much do you tell this child that this child did a good job?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc27",  # pcrc_pcc27
        "ElementDescription": (
            "Child. How much does your mother tell you what to do? "
            "Parent. How much do you tell this child what to do?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc28",  # pcrc_pcc28
        "ElementDescription": (
            "Child. How much do you and your mother share secrets and private feelings with each other? "
            "Parent. How much do this child and you share secrets and private feelings with each other?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc29",  # pcrc_pcc29
        "ElementDescription": (
            "Child. How much does your mother hit you when you've been bad? "
            "Parent. How much do you hit this child when they have been bad?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc30",  # pcrc_pcc30
        "ElementDescription": (
            "Child. How much do you feel proud of your mother? "
            "Parent. How much do you feel proud of this child?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc31",  # pcrc_pcc31
        "ElementDescription": (
            "Child. ... How much does your mother feel proud of you? "
            "Parent. ... How much does this child feel proud of you?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc32",  # pcrc_pcc32
        "ElementDescription": (
            "Child. How much does your mother forbid you to do something you really like to do when you've been bad? "
            "Parent. How much do you forbid this child to do something this child really likes to do when "
            "they have been bad?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc33",  # pcrc_pcc33
        "ElementDescription": (
            "Child. How much does your mother help you with things you can't do by yourself? "
            "Parent. How much do you help this child with things this child can't do by themselves?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc34",  # pcrc_pcc34
        "ElementDescription": (
            "Child. How much does your mother nag or bug you to do things? "
            "Parent. How much do you nag or bug this child to do things?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc35",  # pcrc_pcc35
        "ElementDescription": (
            "Child. How much does your mother listen to your ideas before making a decision? "
            "Parent. How much do you listen to their ideas before making a decision?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc36",  # pcrc_pcc36
        "ElementDescription": (
            "Child. How much do you play around and have fun with your mother? "
            "Parent. How much does this child play around and have fun with you?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc37",  # pcrc_pcc37
        "ElementDescription": (
            "Child. Some parents make their children feel bad about themselves a lot when they misbehave, "
            "while other parents do this a little. How much does your mother make you feel bad about yourself "
            "when you misbehave? Parent. ... How much do you make this child feel bad about themselves ... ?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc38",  # pcrc_pcc38
        "ElementDescription": (
            "Child. How much does your mother give you reasons for rules she makes for you to follow? "
            "Parent. How much do you give this child reasons for rules she makes ... ?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc39",  # pcrc_pcc39
        "ElementDescription": (
            "Child. How much does your mother want you to be around her all of the time? "
            "Parent. How much do you want this child to be around you all of the time?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcc40",  # pcrc_pcc40
        "ElementDescription": (
            "Child. How much does your mother worry about you when you're not at home? "
            "Parent. How much do you worry about this child when they're not at home?"
        ),
        "Notes": "1=Hardly at all; 2=Not too much; 3=Somewhat; 4=Very much; 5=Extremely much"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcposx",  # pcrc_pcrcposx
        "ElementDescription": "Possessiveness (mean score)",
        "Notes": "Includes Items: 1, 20, 39"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcprox",  # pcrc_pcrcprox
        "ElementDescription": "Protectiveness (mean score)",
        "Notes": "Includes Items: 2, 21, 40."
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcaffx",  # pcrc_pcrcaffx
        "ElementDescription": "Affection (mean score)",
        "Notes": "Includes Items: 3, 22"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcqurx",  # pcrc_pcrcqurx
        "ElementDescription": "Quarreling (mean score)",
        "Notes": "Includes Items: 4, 23"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcsocx",  # pcrc_pcrcsocx
        "ElementDescription": "Pro-social (mean score)",
        "Notes": "Includes Items: 5, 24"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcsimx",  # pcrc_pcrcsimx
        "ElementDescription": "Similarity (mean score)",
        "Notes": "Includes Items: 6, 25"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcprax",  # pcrc_pcrcprax
        "ElementDescription": "Praise (mean score)",
        "Notes": "Includes Items: 7, 26."
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcdomx",  # pcrc_pcrcdomx
        "ElementDescription": "Dominance (mean score)",
        "Notes": "Includes Items: 8, 27"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcintx",  # pcrc_pcrcintx
        "ElementDescription": "Intimacy (mean score)",
        "Notes": "Includes Items: 9, 28."
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcppnx",  # pcrc_pcrcppnx
        "ElementDescription": "Physical Punishment (mean score)",
        "Notes": "Includes Items: 10, 29"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcadpx",  # pcrc_pcrcadpx
        "ElementDescription": "Admiration of Parent (mean score)",
        "Notes": "Includes Items: 11, 30"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcadcx",  # pcrc_pcrcadcx
        "ElementDescription": "Admiration by Parent (mean score)",
        "Notes": "Includes Items: 12, 31"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcprix",  # pcrc_pcrcprix
        "ElementDescription": "Deprivation of Privileges (mean score)",
        "Notes": "Includes Items: 13, 32"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcnurx",  # pcrc_pcrcnurx
        "ElementDescription": "Nurturance (mean score)",
        "Notes": "Includes Items: 14, 33"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcvpnx",  # pcrc_pcrcvpnx
        "ElementDescription": "Verbal Punishment (mean score)",
        "Notes": "Includes Items: 15, 34"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcdecx",  # pcrc_pcrcdecx
        "ElementDescription": "Shared Decision Making (mean score)",
        "Notes": "Includes Items: 16, 35"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrccomx",  # pcrc_pcrccomx
        "ElementDescription": "Companionship (mean score)",
        "Notes": "Includes Items: 17, 36"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcgltx",  # pcrc_pcrcgltx
        "ElementDescription": "Guilt Induction (mean score)",
        "Notes": "Includes Items: 18, 37"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcratx",  # pcrc_pcrcratx
        "ElementDescription": "Rationale (mean score)",
        "Notes": "Includes Items: 19, 38"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcpox",  # pcrc_pcrcpox
        "ElementDescription": "Possessiveness & Protectiveness (mean score)",
        "Notes": "Includes Items: 1, 2, 20, 21, 39, 40"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcwx",  # pcrc_pcrcwx
        "ElementDescription": (
            "Affection, Admiration of Parent & Admiration by Parent (mean score)"
        ),
        "Notes": "Includes Items: 3, 11, 12, 22, 30, 31"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcpax",  # pcrc_pcrcpax
        "ElementDescription": (
            "Quarreling, Dominance, Physical Punishment, Deprivation of Privileges, "
            "Verbal Punishment & Guilt Induction (mean score)"
        ),
        "Notes": "Includes Items: 4, 8, 10, 13, 15, 18, 23, 27, 29, 32, 34, 37"
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcprx",  # pcrc_pcrcprx
        "ElementDescription": (
            "Pro-social, Similarity, Intimacy, Nurturance & Companionship (mean score)"
        ),
        "Notes": "Includes Items: 5, 6, 9, 14, 17, 24, 25, 28, 33, 36."
    },
    {
        "Questionnaire": "pcrc",
        "ElementName": "pcrcdwx",  # pcrc_pcrcdwx
        "ElementDescription": "Praise, Shared Decision Making & Rationale (mean score)",
        "Notes": "Includes Items: 7, 16, 19, 26, 35, 38"
    }
]

# Convert to a pandas DataFrame
df_pcrc = pd.DataFrame(data)

# Show or return the dataframe

# %%
data = [
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t35",  # ssrs_s7t35
        "ElementDescription": "How often - controls temper in conflict situations with peers",
        "Notes": "0= Never; 1= Sometimes; 2= Very often; 999= Missing"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t36",  # ssrs_s7t36
        "ElementDescription": "How important - controls temper in conflict situations with peers",
        "Notes": "0=Not important; 1=Important; 2=Critical"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t45",  # ssrs_s7t45
        "ElementDescription": "How often - controls temper in conflict situations with adults",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t46",  # ssrs_s7t46
        "ElementDescription": "How important - controls temper in conflict situations with adults",
        "Notes": "0=Not important; 1=Important; 2=Critical"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst15",  # ssrs_sst15
        "ElementDescription": "How often - uses free time in an acceptable way",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst16",  # ssrs_sst16
        "ElementDescription": "How important - uses free time in an acceptable way",
        "Notes": "0=Not important; 1=Important; 2=Critical"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst19",  # ssrs_sst19
        "ElementDescription": "How often - makes friends easily",
        "Notes": "0= Never; 1= Sometimes; 2= Very often; 999= Missing"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst20",  # ssrs_sst20
        "ElementDescription": "How important - makes friends easily",
        "Notes": "0=Not important; 1=Important; 2=Critical"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst37",  # ssrs_sst37
        "ElementDescription": "How often - gives compliments to peers",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst38",  # ssrs_sst38
        "ElementDescription": "How important - gives compliments to peers",
        "Notes": "0=Not important; 1=Important; 2=Critical"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst43",  # ssrs_sst43
        "ElementDescription": "How often - cooperates with peers/family mmebers without prompting",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst44",  # ssrs_sst44
        "ElementDescription": "How important - cooperates with peers/family members without prompting",
        "Notes": "0=Not important; 1=Important; 2=Critical"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst47",  # ssrs_sst47
        "ElementDescription": "How often - joins ongoing activity or group without being told to do so",
        "Notes": "0= Never; 1= Sometimes; 2= Very often; 999= Missing"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst48",  # ssrs_sst48
        "ElementDescription": "How important - joins ongoing activity or group without being told to do so",
        "Notes": "0=Not important; 1=Important; 2=Critical"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t62",  # ssrs_s7t62
        "ElementDescription": "How often - fights with others",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t63",  # ssrs_s7t63
        "ElementDescription": "How often - is easily embarrassed",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t64",  # ssrs_s7t64
        "ElementDescription": "How often - argues with others",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t65",  # ssrs_s7t65
        "ElementDescription": "How often - threatens or bullies others",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t66",  # ssrs_s7t66
        "ElementDescription": "How often - talks back to adults when corrected",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t67",  # ssrs_s7t67
        "ElementDescription": "How often - has temper tantrums",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t68",  # ssrs_s7t68
        "ElementDescription": "How often - appears lonely",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t69",  # ssrs_s7t69
        "ElementDescription": "How often - gets angry easily",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t70",  # ssrs_s7t70
        "ElementDescription": "How often - shows anxiety about being with a group of children",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t71",  # ssrs_s7t71
        "ElementDescription": "How often - acts sad or depressed",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "s7t72",  # ssrs_s7t72
        "ElementDescription": "How often - has low self esteem",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst65",  # ssrs_sst65
        "ElementDescription": "How often - is easily distracted",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst67",  # ssrs_sst67
        "ElementDescription": "How often - disturbs ongoing activities",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst70",  # ssrs_sst70
        "ElementDescription": "How often - doesnt listen to what others say",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst77",  # ssrs_sst77
        "ElementDescription": "How often - acts impulsively",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sst78",  # ssrs_sst78
        "ElementDescription": "How often - fidgets or moves excessively",
        "Notes": "0=Never; 1=Sometimes; 2=Very often"
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sspcoopt",  # ssrs_sspcoopt
        "ElementDescription": "Cooperation std score",
        "Notes": ""
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sspasrtt",  # ssrs_sspasrtt
        "ElementDescription": "Assertiveness std score",
        "Notes": ""
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sspscont",  # ssrs_sspscont
        "ElementDescription": "Social Conduct std score",
        "Notes": ""
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "ssptosst",  # ssrs_ssptosst
        "ElementDescription": "Social skills std score",
        "Notes": ""
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sspextt",  # ssrs_sspextt
        "ElementDescription": "Externalizing behavior std score",
        "Notes": ""
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "sspintt",  # ssrs_sspintt
        "ElementDescription": "Internalizinb behavior std score",
        "Notes": ""
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "ssphypt",  # ssrs_ssphypt
        "ElementDescription": "Hyperactive std score",
        "Notes": ""
    },
    {
        "Questionnaire": "ssrs",
        "ElementName": "ssptopbt",  # ssrs_ssptopbt
        "ElementDescription": "Total problem behaviors total score",
        "Notes": ""
    }
]

df_ssrs = pd.DataFrame(data)

# %%
data = [
    {
        "Questionnaire": "scid",
        "ElementName": "q092_phobia_life",  # scid_q092_phobia_life
        "ElementDescription": "Specific Phobia Lifetime Prevalence",
        "Notes": "0::3; -999   → 0 = Inadequate Information; 1 = Absent; 2 = Sub-Threshold; 3 = Threshold; -999=NA/NK/Missing"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q094_ocd_life",  # scid_q094_ocd_life
        "ElementDescription": "Obsessive Compulsive Disorder Lifetime Prevalence",
        "Notes": "0;1;2;3;999   → 0 = Inadequate Information;1 = Absent;2 = Sub-Threshold;3 = Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q114_an_life",  # scid_q114_an_life
        "ElementDescription": "Annorexia Nervosa Lifetime Prevalence",
        "Notes": "0::3; -999   → 0 = Inadequate Information;1 = Absent;2 = Sub-Threshold;3 = Threshold; -999=NA/NK/Missing"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q116_bn_life",  # scid_q116_bn_life
        "ElementDescription": "Bulimia Nervosa Lifetime Prevalence",
        "Notes": "0::3; -999   → 0 = Inadequate Information;1 = Absent;2 = Sub-Threshold;3 = Threshold; -999=NA/NK/Missing"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "bpl",  # scid_bpl
        "ElementDescription": "Bipolar lifetime",
        "Notes": "0::3   → 0=Inadequate Information;1=Absent;2=Sub-Threshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "gadc",  # scid_gadc
        "ElementDescription": "Generalized Anxiety Disorder current",
        "Notes": "0::3; -999   → 0=Inadequate Information;1=Absent;2=Sub-Threshold;3=Threshold; -999=NA/NK/Missing"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "somatc",  # scid_somatc
        "ElementDescription": "Somatization disorder current",
        "Notes": "0::3   → 0 = Inadequate Information;1 = Absent;2 = Sub-Threshold;3 = Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "undfsomc",  # scid_undfsomc
        "ElementDescription": "Undifferentiated somatoform disorder current",
        "Notes": "0::3   → 0 = Inadequate Information;1 = Absent;2 = Sub-Threshold;3 = Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "hypoconc",  # scid_hypoconc
        "ElementDescription": "Hypochondriasis current",
        "Notes": "0::3   → 0 = Inadequate Information;1 = Absent;2 = Sub-Threshold;3 = Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "othdsml",  # scid_othdsml
        "ElementDescription": "Other DSM-III-R Axis I disorder lifetime",
        "Notes": "0::3   → 0=Inadequate Information;1=Absent;2=Sub-Threshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "axisidx",  # scid_axisidx
        "ElementDescription": "Principal Axis I diagnosis current",
        "Notes": (
            "0 = No current Axis I Disorder;1 = Bipolar Disorder; 2 = Other Bipolar; 3 = Major Depression; 4 = Dysthymia; "
            "5 = Depressive Syndrome superimposed on Chronic Psychotic Disorder; 12=Alcohol; 13=Sedative-Hypnotic-Anxiolytic; "
            "14=Cannabis;15=Stimulant;16=Opioid;17=Cocaine;18=Hallucinogens/PCP;19=Poly Drug;20=Other psychoactive substance;21=Panic; "
            "22=Agoraphobia;23=Social Phobia;24=Simple Phobia;25=OCD;26=GAD;27=Somatization;28=Somatoform Pain;29=Undifferentiated "
            "Somatoform;30=Hypochondriasis;31=Anorexia;32=Bulimia;33=Adjustment;34=Other Axis I;99=Unknown"
        )
    },
    {
        "Questionnaire": "scid",
        "ElementName": "certmood",  # scid_certmood
        "ElementDescription": "Certainty of presence of at least one or absence of any mood disorder",
        "Notes": "1::3   → 1=Poor; 2=Fair; 3=Good"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "certsubs",  # scid_certsubs
        "ElementDescription": "Certainty of presence of at least one or absence of any psychoactive substance use disorder",
        "Notes": "1::3   → 1=Poor; 2=Fair; 3=Good"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "certanx",  # scid_certanx
        "ElementDescription": "Certainty of presence of at least one or absence of any anxiety disorder",
        "Notes": "1::3   → 1=Poor; 2=Fair; 3=Good"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "certsom",  # scid_certsom
        "ElementDescription": "Certainty of presence of at least one or absence of any somatoform disorder",
        "Notes": "1::3   → 1=Poor; 2=Fair; 3=Good"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "certeat",  # scid_certeat
        "ElementDescription": "Certainty of presence of at least one or absence of any eating disorder",
        "Notes": "1::3   → 1=Poor; 2=Fair; 3=Good"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "certadj",  # scid_certadj
        "ElementDescription": "Certainty of presence of at least one or absence of any adjustment disorder",
        "Notes": "1::3   → 1=Poor; 2=Fair; 3=Good"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "ethnic_group",  # scid_ethnic_group
        "ElementDescription": "Ethnic group",
        "Notes": ""
    },
    {
        "Questionnaire": "scid",
        "ElementName": "das1ms",  # scid_das1ms
        "ElementDescription": "Marital status",
        "Notes": ""
    },
    {
        "Questionnaire": "scid",
        "ElementName": "grade_highed",  # scid_grade_highed
        "ElementDescription": "Grade/Highest education",
        "Notes": (
            "1= Less than 6th grade; 2= Some high school; 3= High school diploma or GED; 4= Some college; 5= Associates; "
            "6= Bachelors; 7= Some graduate; 8= Masters+; 9= Some post-grad; 10= Completed 8th; 11= High school; 12= College/Univ; "
            "13= Grad school;14= Other;15=Less than high school;99=Not available"
        )
    },
    {
        "Questionnaire": "scid",
        "ElementName": "pastpsy",  # scid_pastpsy
        "ElementDescription": "Treatment for emotional problems with a physician or mental health professional",
        "Notes": "1;2 → 1=No; 2=Yes"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "scid19",  # scid_scid19
        "ElementDescription": "Number previous hospitalizations lifetime",
        "Notes": ""
    },
    {
        "Questionnaire": "scid",
        "ElementName": "mdca1",  # scid_mdca1
        "ElementDescription": "Depressed mood",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "mdca2",  # scid_mdca2
        "ElementDescription": "Loss of interest or pleasure",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "maniachk",  # scid_maniachk
        "ElementDescription": "No basis for suspecting a current manic syndrome",
        "Notes": "1;2 → 1=Yes; 2=No"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "mala",  # scid_mala
        "ElementDescription": "Criteria A Distinct period of abnormality (Hypomania, at least 4 days)",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "dyschk",  # scid_dyschk
        "ElementDescription": "If overview indicates Psychotic Disorder or Major Depressive or Hypomanic or Manic Episode",
        "Notes": "1;2 → 1=Yes;2=No"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "dya",  # scid_dya
        "ElementDescription": "Criteria A Depressed mood",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "psref",  # scid_psref
        "ElementDescription": "Delusions of reference presence/absence",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "psper",  # scid_psper
        "ElementDescription": "Persecutory delusions presence/absence",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "psgra",  # scid_psgra
        "ElementDescription": "Grandiose delusions presence/absence",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "pssom",  # scid_pssom
        "ElementDescription": "Somatic delusions presence/absence",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "psaud",  # scid_psaud
        "ElementDescription": "Auditory hallucinations presence/absence",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "psvis",  # scid_psvis
        "ElementDescription": "Visual hallucinations presence/absence",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "pstac",  # scid_pstac
        "ElementDescription": "Tactile hallucinations presence/absence",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "psnotorg",  # scid_psnotorg
        "ElementDescription": "Hallucinations - any item coded '3' in 'not organic' section",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "mochk1",  # scid_mochk1
        "ElementDescription": "Never a Major Depressive OR Manic or Hypomanic Episode",
        "Notes": "1;2 → 1=Yes;2=No"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "sualchk",  # scid_sualchk
        "ElementDescription": (
            "No suggestion that ever drank alcohol excessively or had problems"
        ),
        "Notes": "1;2 → 1=Yes;2=No"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "sesed",  # scid_sesed
        "ElementDescription": "Sedatives-hypnotics-anxiolytics",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "sucan",  # scid_sucan
        "ElementDescription": "Cannabis",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "susti",  # scid_susti
        "ElementDescription": "Stimulants",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "suopi",  # scid_suopi
        "ElementDescription": "Opioids",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "sucoc",  # scid_sucoc
        "ElementDescription": "Cocaine",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "suhal",  # scid_suhal
        "ElementDescription": "Hallucinogens/PCP",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "suoth",  # scid_suoth
        "ElementDescription": "Other",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "suany",  # scid_suany
        "ElementDescription": "Any drug groups coded '2' or '3'",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "axpana",  # scid_axpana
        "ElementDescription": "Criteria A One or more panic attacks",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "axawpa",  # scid_axawpa
        "ElementDescription": "Criteria A Fear of difficult escape (Agoraphobia w/o Panic Disorder)",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "axsoca",  # scid_axsoca
        "ElementDescription": "Criteria A Fear of social scrutiny (Social Phobia)",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "axsima",  # scid_axsima
        "ElementDescription": "Criteria A Fear of circumscribed stimulus (Simple/Specific Phobia)",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "axoca1",  # scid_axoca1
        "ElementDescription": "Obsessive recurrent and persistent ideas, thoughts, impulses, or images",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "axoc1",  # scid_axoc1
        "ElementDescription": (
            "Compulsive repetitive, purposeful, intentional behaviors in response to obsession"
        ),
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "axgada",  # scid_axgada
        "ElementDescription": "Unrealistic or excessive anxiety (Generalized Anxiety Disorder Criteria A)",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "smchk1",  # scid_smchk1
        "ElementDescription": "Current Psychotic Disorder OR Residual Phase of Schizophrenia",
        "Notes": "1;2 → 1=Yes; 2=No"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "smchk2",  # scid_smchk2
        "ElementDescription": "Nothing suggests current Somatoform Disorder",
        "Notes": "1;2 → 1=Yes;2=No"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "edanoa",  # scid_edanoa
        "ElementDescription": "Refusal to maintain body weight (Anorexia Nervosa Criterion A)",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "edbula",  # scid_edbula
        "ElementDescription": "Recurrent episodes of binge eating (Bulimia Nervosa Criterion A)",
        "Notes": "0::3 → 0=Inadequate info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "adjchk",  # scid_adjchk
        "ElementDescription": (
            "No current disturbance that does not meet another disorder (Adjustment D/O check)"
        ),
        "Notes": "1;2 → 1=Yes;2=No"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q018_obp_life",  # scid_q018_obp_life
        "ElementDescription": "Other Bipolar Lifetime Prevalence",
        "Notes": "0::3;-8;-9 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;-8=N/A;-9=Missing"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q021_mdd_life",  # scid_q021_mdd_life
        "ElementDescription": "Major Depressive Disorder Lifetime Prevalence",
        "Notes": "0::3;-8;999"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q028_dysd_current",  # scid_q028_dysd_current
        "ElementDescription": "Dyshtimic Disorder Current Episode",
        "Notes": "0;1;2;3 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q067_al_life",  # scid_q067_al_life
        "ElementDescription": "Alcohol Lifetime Prevalence",
        "Notes": "0::5 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;4=Abuse;5=Dependence"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q069_sha_life",  # scid_q069_sha_life
        "ElementDescription": (
            "Sedative-Hypnotic-Anxiolytic Lifetime Prevalence"
        ),
        "Notes": (
            "0::5;-8;-9 → 0=Inadequate Info; 1=Absent; 2=Sub-Threshold; 3=Threshold; 4=Abuse; "
            "5=Dependence; -8=N/A; -9=Missing"
        )
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q071_can_life",  # scid_q071_can_life
        "ElementDescription": "Cannabis Lifetime Prevalence",
        "Notes": (
            "0::5;-8;-9 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;4=Abuse;5=Dependence;"
            " -8=N/A; -9=Missing"
        )
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q073_stim_life",  # scid_q073_stim_life
        "ElementDescription": "Stimulants Lifetime Prevalence",
        "Notes": (
            "0::5;-8;-9 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;4=Abuse;5=Dependence;"
            "-8=N/A; -9=Missing"
        )
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q075_op_life",  # scid_q075_op_life
        "ElementDescription": "Opiod Lifetime Prevalence",
        "Notes": "0::5 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;4=Abuse;5=Dependence"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q077_coc_life",  # scid_q077_coc_life
        "ElementDescription": "Cocaine Lifetime Prevalence",
        "Notes": "0::5 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;4=Abuse;5=Dependence"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q079_hal_life",  # scid_q079_hal_life
        "ElementDescription": "Hallucinogen/PCP Lifetime Prevalence",
        "Notes": "0::5 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;4=Abuse;5=Dependence"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q081_poly_life",  # scid_q081_poly_life
        "ElementDescription": "Polysubstance Lifetime Prevalence",
        "Notes": "0::5 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;4=Abuse;5=Dependence"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q083_othsub_life",  # scid_q083_othsub_life
        "ElementDescription": "Other Substance Lifetime Prevalence",
        "Notes": "0::5 → 0=Inadequate Info;1=Absent;2=Sub-Threshold;3=Threshold;4=Abuse;5=Dependence"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q085_panic_life",  # scid_q085_panic_life
        "ElementDescription": "Panic Disorder Lifetime Prevalence",
        "Notes": "0::3; -999"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q088_agor_life",  # scid_q088_agor_life
        "ElementDescription": "Agoraphobia without Panic Disorder Lifetime Prevalence",
        "Notes": "0::3; -999"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "q090_social_life",  # scid_q090_social_life
        "ElementDescription": "Social Phobia Lifetime Prevalence",
        "Notes": "0::3; -999"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "depsnpdl",  # scid_depsnpdl
        "ElementDescription": (
            "Depressive syndrome superimposed on chronic psychotic disorder lifetime"
        ),
        "Notes": "0::3 → 0=Inadequate Info;1=Absent;2=Subthreshold;3=Threshold"
    },
    {
        "Questionnaire": "scid",
        "ElementName": "sompainc",  # scid_sompainc
        "ElementDescription": "Somatoform pain disorder current",
        "Notes": "0::3 → 0=Inadequate Info;1=Absent;2=Subthreshold;3=Threshold"
    }
]

df_scid = pd.DataFrame(data)
df_scid
# Out:
#    Questionnaire       ElementName  \
# 0           scid  q092_phobia_life
# 1           scid     q094_ocd_life
# 2           scid      q114_an_life
# 3           scid      q116_bn_life
# 4           scid               bpl
# ..           ...               ...
# 70          scid   q085_panic_life
# 71          scid    q088_agor_life
# 72          scid  q090_social_life
# 73          scid          depsnpdl
# 74          scid          sompainc
#
#                                    ElementDescription  \
# 0                 Specific Phobia Lifetime Prevalence
# 1   Obsessive Compulsive Disorder Lifetime Prevalence
# 2               Annorexia Nervosa Lifetime Prevalence
# 3                 Bulimia Nervosa Lifetime Prevalence
# 4                                    Bipolar lifetime
# ..                                                ...
# 70                 Panic Disorder Lifetime Prevalence
# 71  Agoraphobia without Panic Disorder Lifetime Pr...
# ...
