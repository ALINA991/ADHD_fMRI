# %%
import pandas as pd
from pathlib import Path

# %%
if Path('/Volumes/Samsung_T5/MIT/mta').exists():
    data_root =     '/Volumes/Samsung_T5/MIT/mta'
    derived_data= '/Volumes/Samsung_T5/MIT/mta/output/derived_data'
else: 
    data_root = '/Users/alina/Desktop/MIT/code/data'
    derived_data = '/Users/alina/Desktop/MIT/code/data/output/derived_data'

# %%
columns = [
    'Outcome Domain', 'Measure and Rater',
    'Combined Treatment Baseline (SD)', 'Combined Treatment Baseline [No. of Subjects]',
    'Combined Treatment 14 mo (SD)', 'Combined Treatment 14 mo [No. of Subjects]',
    'Medication Management Baseline (SD)', 'Medication Management Baseline [No. of Subjects]',
    'Medication Management 14 mo (SD)', 'Medication Management 14 mo [No. of Subjects]',
    'Behavioral Treatment Baseline (SD)', 'Behavioral Treatment Baseline [No. of Subjects]',
    'Behavioral Treatment 14 mo (SD)', 'Behavioral Treatment 14 mo [No. of Subjects]',
    'Assessment and Referral Baseline (SD)', 'Assessment and Referral Baseline [No. of Subjects]',
    'Assessment and Referral 14 mo (SD)', 'Assessment and Referral 14 mo [No. of Subjects]'
]

# Manually input the data as lists of lists
data = [
    ['ADHD symptoms', 'Inattention Teacher', '2.16 (0.67)', 137, '1.12 (0.75)', 134, '2.27 (0.61)', 135, '1.11 (0.77)', 120, '2.28 (0.64)', 136, '1.47 (0.81)', 119, '2.19 (0.69)', 135, '1.48 (0.82)', 128],
    ['ADHD symptoms', 'Inattention Parent', '2.07 (0.61)', 140, '1.02 (0.66)', 133, '2.03 (0.64)', 140, '1.12 (0.70)', 121, '1.99 (0.63)', 139, '1.40 (0.68)', 129, '2.05 (0.65)', 142, '1.49 (0.67)', 130],
    ['ADHD symptoms', 'Hyperactive/impulsive Teacher', '1.89 (0.77)', 137, '0.75 (0.71)', 134, '2.08 (0.71)', 135, '0.82 (0.69)', 120, '2.05 (0.75)', 136, '1.10 (0.77)', 119, '1.93 (0.81)', 135, '1.25 (0.84)', 128],
    ['ADHD symptoms', 'Hyperactive/impulsive Parent', '1.91 (0.69)', 140, '1.85 (0.63)', 133, '1.89 (0.62)', 140, '0.91 (0.65)', 121, '1.89 (0.64)', 140, '1.24 (0.72)', 129, '1.95 (0.67)', 142, '1.35 (0.72)', 130],
    ['ADHD symptoms', 'Classroom observer', '0.33 (0.22)', 122, '0.21 (0.20)', 114, '0.31 (0.21)', 119, '0.16 (0.15)', 110, '0.37 (0.26)', 120, '0.29 (0.26)', 107, '0.38 (0.27)', 118, '0.18 (0.09)', 109],
    ['Aggression-ODD', 'ODD aggression Teacher', '1.29 (0.91)', 137, '0.61 (0.68)', 134, '1.39 (0.92)', 135, '0.65 (0.68)', 120, '1.43 (0.86)', 136, '0.97 (0.80)', 119, '1.35 (0.88)', 135, '1.00 (0.84)', 128],
    ['Aggression-ODD', 'ODD aggression Parent', '1.39 (0.71)', 140, '0.76 (0.64)', 133, '1.45 (0.80)', 139, '0.94 (0.74)', 121, '1.37 (0.70)', 140, '1.05 (0.74)', 129, '1.49 (0.70)', 142, '1.11 (0.67)', 130],
    ['Aggression-ODD', 'Classroom observer', '0.018 (0.038)', 122, '0.007 (0.015)', 114, '0.014 (0.025)', 119, '0.004 (0.011)', 108, '0.020 (0.046)', 120, '0.010 (0.018)', 107, '0.019 (0.026)', 118, '0.006 (0.014)', 109],
    ['Internalizing symptoms', 'SSRS internalizing symptoms Teacher', '0.73 (0.51)', 113, '0.68 (0.44)', 108, '0.79 (0.47)', 117, '0.63 (0.47)', 99, '0.82 (0.45)', 115, '0.58 (0.40)', 102, '0.78 (0.44)', 115, '0.69 (0.44)', 105],
    ['Internalizing symptoms', 'SSRS internalizing symptoms Parent', '0.98 (0.37)', 138, '0.67 (0.37)', 127, '0.97 (0.37)', 137, '0.67 (0.39)', 120, '0.93 (0.43)', 133, '0.77 (0.40)', 131, '0.97 (0.35)', 137, '0.82 (0.43)', 125],
    ['Internalizing symptoms', 'MASC Child', '2.58 (0.47)', 144, '2.33 (0.47)', 133, '2.48 (0.49)', 143, '2.22 (0.47)', 125, '2.46 (0.55)', 143, '2.27 (0.49)', 132, '2.49 (0.58)', 145, '2.27 (0.45)', 124],
    ['Social skills', 'SSRS Teacher', '0.84 (0.29)', 113, '1.19 (0.30)', 108, '0.83 (0.31)', 117, '1.15 (0.32)', 99, '0.80 (0.25)', 115, '1.06 (0.32)', 102, '0.87 (0.29)', 115, '1.05 (0.31)', 105],
    ['Social skills', 'SSRS Parent', '1.04 (0.23)', 138, '1.02 (0.27)', 133, '1.01 (0.24)', 137, '1.17 (0.26)', 120, '1.02 (0.22)', 133, '1.15 (0.24)', 131, '1.03 (0.23)', 137, '1.15 (0.24)', 125],
    ['Social skills', 'Sociometrics Peers', '...', '...', '...', '...', '...', '...', '...', '...', '3.23 (1.03)', 69, '...', '...', '3.05 (0.82)', 65],
    ['Parent-child relations', 'Power assertion Parent', '2.66 (0.54)', 141, '2.31 (0.56)', 133, '2.75 (0.56)', 140, '2.46 (0.57)', 122, '2.75 (0.50)', 141, '2.47 (0.51)', 143, '2.71 (0.57)', 142, '2.52 (0.57)', 130],
    ['Parent-child relations', 'Personal closeness Parent', '3.56 (0.52)', 141, '3.50 (0.48)', 134, '3.58 (0.49)', 140, '3.55 (0.52)', 122, '3.52 (0.49)', 141, '3.59 (0.48)', 132, '3.58 (0.48)', 142, '3.63 (0.49)', 124],
    ['Academic achievement', "Child's scores Reading", '96.5 (14.6)', 154, '93.7 (13.9)', 144, '96.1 (13.7)', 144, '97.9 (14.1)', 144, '95.1 (14.6)', 144, '92.2 (12.5)', 144, '95.5 (14.3)', 146, '95.4 (14.2)', 131],
    ['Academic achievement', "Child's scores Mathematics", '97.9 (15.1)', 145, '97.2 (12.6)', 144, '97.2 (12.6)', 144, '99.7 (13.4)', 144, '97.7 (13.4)', 144, '100.3 (13.7)', 134, '98.6 (14.1)', 146, '100.4 (15.2)', 131],
    ['Academic achievement', "Child's scores Spelling", '95.1 (14.8)', 144, '92.8 (12.5)', 144, '95.2 (13.1)', 144, '96.0 (14.8)', 144, '92.8 (12.5)', 144, '93.7 (13.9)', 144, '95.2 (13.1)', 146, '94.2 (14.1)', 131],
]

# Create the DataFrame
df = pd.DataFrame(data, columns=columns)

# Display the DataFrame
print(df)
# Out:
#             Outcome Domain                    Measure and Rater  \
# 0            ADHD symptoms                  Inattention Teacher
# 1            ADHD symptoms                   Inattention Parent
# 2            ADHD symptoms        Hyperactive/impulsive Teacher
# 3            ADHD symptoms         Hyperactive/impulsive Parent
# 4            ADHD symptoms                   Classroom observer
# 5           Aggression-ODD               ODD aggression Teacher
# 6           Aggression-ODD                ODD aggression Parent
# 7           Aggression-ODD                   Classroom observer
# 8   Internalizing symptoms  SSRS internalizing symptoms Teacher
# 9   Internalizing symptoms   SSRS internalizing symptoms Parent
# 10  Internalizing symptoms                           MASC Child
# 11           Social skills                         SSRS Teacher
# 12           Social skills                          SSRS Parent
# 13           Social skills                   Sociometrics Peers
# ...

# %%
df['Combined Treatment 14 mo (SD)']
# Out:
# 0       1.12 (0.75)
# 1       1.02 (0.66)
# 2       0.75 (0.71)
# 3       1.85 (0.63)
# 4       0.21 (0.20)
# 5       0.61 (0.68)
# 6       0.76 (0.64)
# 7     0.007 (0.015)
# 8       0.68 (0.44)
# 9       0.67 (0.37)
# 10      2.33 (0.47)
# 11      1.19 (0.30)
# 12      1.02 (0.27)
# 13              ...
# 14      2.31 (0.56)
# 15      3.50 (0.48)
# 16      93.7 (13.9)
# 17      97.2 (12.6)
# 18      92.8 (12.5)
# Name: Combined Treatment 14 mo (SD), dtype: object

# %%
columns_rr = ['Outcome Domain', 'Measure and Rater', 'Test', 'F_value', 'P_value']

# Manually input the data as lists of lists
data_rr = [
    ['ADHD symptoms', 'Inattention - Teacher', 'Treatment x time', 10.6, '<.001'],
    ['ADHD symptoms', 'Inattention - Teacher', 'Treatment x site', 0.9, '.56'],
    ['ADHD symptoms', 'Inattention - Teacher', 'Site', 2.7, '.02'],
    ['ADHD symptoms', 'Inattention - Parent', 'Treatment x time', 21.5, '<.001'],
    ['ADHD symptoms', 'Inattention - Parent', 'Treatment x site', 0.6, '.88'],
    ['ADHD symptoms', 'Inattention - Parent', 'Site', 3.0, '.02'],
    ['ADHD symptoms', 'Hyperactive-impulsive - Teacher', 'Treatment x time', 10.0, '<.001'],
    ['ADHD symptoms', 'Hyperactive-impulsive - Teacher', 'Treatment x site', 1.3, '.49'],
    ['ADHD symptoms', 'Hyperactive-impulsive - Teacher', 'Site', 3.0, '.02'],
    ['ADHD symptoms', 'Hyperactive-impulsive - Parent', 'Treatment x time', 21.5, '<.001'],
    ['ADHD symptoms', 'Hyperactive-impulsive - Parent', 'Treatment x site', 1.3, '.23'],
    ['ADHD symptoms', 'Hyperactive-impulsive - Parent', 'Site', 4.4, '.0006'],
    ['ADHD symptoms', 'Classroom observer', 'Treatment x time', 2.6, '.05'],
    ['ADHD symptoms', 'Classroom observer', 'Treatment x site', 1.5, '.11'],
    ['ADHD symptoms', 'Classroom observer', 'Site', 11.5, '<.001'],
    ['Aggression-ODD', 'ODD = aggression - Teacher', 'Treatment x time', 6.5, '.0003'],
    ['Aggression-ODD', 'ODD = aggression - Teacher', 'Treatment x site', 1.2, '.25'],
    ['Aggression-ODD', 'ODD = aggression - Teacher', 'Site', 4.2, '.001'],
    ['Aggression-ODD', 'ODD = aggression - Parent', 'Treatment x time', 7.4, '<.001'],
    ['Aggression-ODD', 'ODD = aggression - Parent', 'Treatment x site', 1.1, '.40'],
    ['Aggression-ODD', 'ODD = aggression - Parent', 'Site', 4.3, '.0007'],
    ['Aggression-ODD', 'Classroom observer', 'Treatment x time', 6.9, '.10'],
    ['Aggression-ODD', 'Classroom observer', 'Treatment x site', 18.5, '.30'],
    ['Aggression-ODD', 'Classroom observer', 'Site', 85.4, '<.001'],
    ['Internalizing symptoms', 'SSRS Internalizing - Teacher', 'Treatment x time', 2.1, '.10'],
    ['Internalizing symptoms', 'SSRS Internalizing - Teacher', 'Treatment x site', 0.5, '.92'],
    ['Internalizing symptoms', 'SSRS Internalizing - Teacher', 'Site', 1.6, '.17'],
    ['Internalizing symptoms', 'SSRS Internalizing - Parent', 'Treatment x time', 9.2, '<.001'],
    ['Internalizing symptoms', 'SSRS Internalizing - Parent', 'Treatment x site', 1.1, '.35'],
    ['Internalizing symptoms', 'SSRS Internalizing - Parent', 'Site', 2.2, '.05'],
    ['Internalizing symptoms', 'MASC Child', 'Treatment x time', 0.6, '.65'],
    ['Internalizing symptoms', 'MASC Child', 'Treatment x site', 0.07, '.78'],
    ['Internalizing symptoms', 'MASC Child', 'Site', 2.2, '.05'],
    ['Social skills', 'SSRS - Teacher', 'Treatment x time', 6.1, '.0004'],
    ['Social skills', 'SSRS - Teacher', 'Treatment x site', 0.05, '.96'],
    ['Social skills', 'SSRS - Teacher', 'Site', 3.9, '.002'],
    ['Social skills', 'SSRS - Parent', 'Treatment x time', 2.2, '.09'],
    ['Social skills', 'SSRS - Parent', 'Treatment x site', 1.0, '.86'],
    ['Social skills', 'SSRS - Parent', 'Site', 3.8, '.02'],
    ['Parent-child relations', 'Power assertion - Parent', 'Treatment x time', 5.6, '.0008'],
    ['Parent-child relations', 'Power assertion - Parent', 'Treatment x site', 1.0, '.45'],
    ['Parent-child relations', 'Power assertion - Parent', 'Site', 2.8, '.02'],
    ['Parent-child relations', 'Personal closeness - Parent', 'Treatment x time', 2.0, '.0008'],
    ['Parent-child relations', 'Personal closeness - Parent', 'Treatment x site', 1.0, '.54'],
    ['Parent-child relations', 'Personal closeness - Parent', 'Site', 1.2, '.32'],
]

# Create the DataFrame
df_rr = pd.DataFrame(data_rr, columns=columns_rr)

# Display the DataFrame
print(df_rr)
# Out:
#             Outcome Domain                Measure and Rater              Test  \
# 0            ADHD symptoms            Inattention - Teacher  Treatment x time
# 1            ADHD symptoms            Inattention - Teacher  Treatment x site
# 2            ADHD symptoms            Inattention - Teacher              Site
# 3            ADHD symptoms             Inattention - Parent  Treatment x time
# 4            ADHD symptoms             Inattention - Parent  Treatment x site
# 5            ADHD symptoms             Inattention - Parent              Site
# 6            ADHD symptoms  Hyperactive-impulsive - Teacher  Treatment x time
# 7            ADHD symptoms  Hyperactive-impulsive - Teacher  Treatment x site
# 8            ADHD symptoms  Hyperactive-impulsive - Teacher              Site
# 9            ADHD symptoms   Hyperactive-impulsive - Parent  Treatment x time
# 10           ADHD symptoms   Hyperactive-impulsive - Parent  Treatment x site
# ...

# %%
results_table = df_rr

# %%
results_table_cols_order = results_table.columns
index_m_r = results_table.columns.get_loc('Measure and Rater')
index_m_r

results_table.loc[results_table['Measure and Rater'] == 'SSRS Teacher', 'Measure and Rater'] = 'SSRS - Teacher'
results_table.loc[results_table['Measure and Rater'] == 'SSRS Parent', 'Measure and Rater'] = 'SSRS - Parent'

results_table[['Measure', 'Rater']] = results_table['Measure and Rater'].str.split(' - ', expand=True)
results_table = results_table.drop(columns=['Measure and Rater'])

results_table.insert(index_m_r, 'Measure', results_table.pop('Measure'))
results_table.insert(index_m_r + 1, 'Rater', results_table.pop('Rater'))

# %%
results_table.loc[results_table['Measure'] == 'SSRS' , 'Measure']= 'SSRS social skills'

# %%
results_table
# Out:
#             Outcome Domain                Measure    Rater              Test  \
# 0            ADHD symptoms            Inattention  Teacher  Treatment x time
# 1            ADHD symptoms            Inattention  Teacher  Treatment x site
# 2            ADHD symptoms            Inattention  Teacher              Site
# 3            ADHD symptoms            Inattention   Parent  Treatment x time
# 4            ADHD symptoms            Inattention   Parent  Treatment x site
# 5            ADHD symptoms            Inattention   Parent              Site
# 6            ADHD symptoms  Hyperactive-impulsive  Teacher  Treatment x time
# 7            ADHD symptoms  Hyperactive-impulsive  Teacher  Treatment x site
# 8            ADHD symptoms  Hyperactive-impulsive  Teacher              Site
# 9            ADHD symptoms  Hyperactive-impulsive   Parent  Treatment x time
# 10           ADHD symptoms  Hyperactive-impulsive   Parent  Treatment x site
# ...

# %%
results_table.reset_index()
results_table.to_csv(Path(derived_data, 'original_rr_results_14.csv'))

# %%
import numpy as np
import pandas as pd

# Define the column structure based on your template
columns = [
    'Outcome Domain', 'Measure', 'Rater', 'replicated F_value',
    'M vs B p_val', 'C vs (M,B) p_val',
    'Comb vs CC p_val', 'Med Mgt vs CC p_val', 'Behav vs CC p_val'
]

# Create an empty DataFrame with the column structure
df_structure = pd.DataFrame(columns=columns)

# Example structure for input (can be updated with actual data later)
data = {
    'Outcome Domain': ['ADHD symptoms', 'ADHD symptoms', 'ADHD symptoms'],
    'Measure': ['Inattention', 'Hyperactive-impulsive', 'Hyperactive-impulsive'],
    'Rater': ['Teacher', 'Teacher', 'Teacher'],
    'replicated F_value': [16.06, 10.00, 11.42],
    'M vs B p_val': ['.000300', 'nan', '.017200'],
    'C vs (M,B) p_val': ['.009200', 'nan', '.017200'],
    'Comb vs CC p_val': ['.005', '.001', 'nan'],
    'Med Mgt vs CC p_val': ['.001', '.004', 'nan'],
    'Behav vs CC p_val': ['.001', '.0035', 'nan']
}

# Adding example data to the structured DataFrame
df_structure = pd.DataFrame(data)

# Function to ensure 3 rows per rater, filling with np.nan if fewer than 3 rows
def fill_to_three(group):
    return group.reindex(range(3), fill_value=np.nan)

# Group by 'Rater' and apply the fill logic
df_grouped = df_structure.groupby('Rater', group_keys=False).apply(fill_to_three)

# Display the final DataFrame
df_grouped
# Out:
# /var/folders/hf/frc4nxb532j7gqr3_36l6kmh0000gn/T/ipykernel_6106/2830320495.py:35: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_grouped = df_structure.groupby('Rater', group_keys=False).apply(fill_to_three)
#   Outcome Domain                Measure    Rater  replicated F_value  \
# 0  ADHD symptoms            Inattention  Teacher               16.06
# 1  ADHD symptoms  Hyperactive-impulsive  Teacher               10.00
# 2  ADHD symptoms  Hyperactive-impulsive  Teacher               11.42
#
#   M vs B p_val C vs (M,B) p_val Comb vs CC p_val Med Mgt vs CC p_val  \
# 0      .000300          .009200             .005                .001
# ...
